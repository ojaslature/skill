# %% [markdown]
# <a href="https://colab.research.google.com/github/ojaslature/skill/blob/main/SKILL_LCA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Filtering

# %%
import pandas as pd
from IPython.display import display
import numpy as np

# %%
#Loading dataset
import pandas as pd

# List of files to concatenate
file_paths = [
    "/content/drive/MyDrive/mini project datasets/UNSW_2018_IoT_Botnet_Full5pc_1.csv",
    "/content/drive/MyDrive/mini project datasets/UNSW_2018_IoT_Botnet_Full5pc_2.csv",
    "/content/drive/MyDrive/mini project datasets/UNSW_2018_IoT_Botnet_Full5pc_3.csv",
    "/content/drive/MyDrive/mini project datasets/UNSW_2018_IoT_Botnet_Full5pc_4.csv"
]


sample_size = 25000  # Exact number of rows to take from each file
dataframes = []

for file in file_paths:
    data = pd.read_csv(file)
    print(f"Original file {file}, shape: {data.shape}")
# Out:
# <ipython-input-12-464cc4429e41>:17: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file)
# Original file /content/drive/MyDrive/mini project datasets/UNSW_2018_IoT_Botnet_Full5pc_1.csv, shape: (1000000, 46)
# <ipython-input-12-464cc4429e41>:17: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file)
# Original file /content/drive/MyDrive/mini project datasets/UNSW_2018_IoT_Botnet_Full5pc_2.csv, shape: (1000000, 46)
# <ipython-input-12-464cc4429e41>:17: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file)
# Original file /content/drive/MyDrive/mini project datasets/UNSW_2018_IoT_Botnet_Full5pc_3.csv, shape: (1000000, 46)
# <ipython-input-12-464cc4429e41>:17: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file)
# Original file /content/drive/MyDrive/mini project datasets/UNSW_2018_IoT_Botnet_Full5pc_4.csv, shape: (668522, 46)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
display(data.describe(),data.info(),data.shape,data.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668522 entries, 0 to 668521
# Data columns (total 46 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   pkSeqID                           668522 non-null  int64
#  1   stime                             668522 non-null  float64
#  2   flgs                              668522 non-null  object
#  3   flgs_number                       668522 non-null  int64
#  4   proto                             668522 non-null  object
#  5   proto_number                      668522 non-null  int64
#  6   saddr                             668522 non-null  object
#  7   sport                             668522 non-null  object
#  8   daddr                             668522 non-null  object
#  9   dport                             668522 non-null  object
#  10  pkts                              668522 non-null  int64
#  11  bytes                             668522 non-null  int64
#  12  state                             668522 non-null  object
#  13  state_number                      668522 non-null  int64
#  14  ltime                             668522 non-null  float64
#  15  seq                               668522 non-null  int64
#  16  dur                               668522 non-null  float64
#  17  mean                              668522 non-null  float64
#  18  stddev                            668522 non-null  float64
#  19  sum                               668522 non-null  float64
#  20  min                               668522 non-null  float64
#  21  max                               668522 non-null  float64
#  22  spkts                             668522 non-null  int64
#  23  dpkts                             668522 non-null  int64
#  24  sbytes                            668522 non-null  int64
#  25  dbytes                            668522 non-null  int64
#  26  rate                              668522 non-null  float64
#  27  srate                             668522 non-null  float64
#  28  drate                             668522 non-null  float64
#  29  TnBPSrcIP                         668522 non-null  int64
#  30  TnBPDstIP                         668522 non-null  int64
#  31  TnP_PSrcIP                        668522 non-null  int64
#  32  TnP_PDstIP                        668522 non-null  int64
#  33  TnP_PerProto                      668522 non-null  int64
#  34  TnP_Per_Dport                     668522 non-null  int64
#  35  AR_P_Proto_P_SrcIP                668522 non-null  float64
#  36  AR_P_Proto_P_DstIP                668522 non-null  float64
#  37  N_IN_Conn_P_DstIP                 668522 non-null  int64
#  38  N_IN_Conn_P_SrcIP                 668522 non-null  int64
#  39  AR_P_Proto_P_Sport                668522 non-null  float64
#  40  AR_P_Proto_P_Dport                668522 non-null  float64
#  41  Pkts_P_State_P_Protocol_P_DestIP  668522 non-null  int64
#  42  Pkts_P_State_P_Protocol_P_SrcIP   668522 non-null  int64
#  43  attack                            668522 non-null  int64
#  44  category                          668522 non-null  object
#  45  subcategory                       668522 non-null  object
# dtypes: float64(15), int64(22), object(9)
# memory usage: 234.6+ MB
#             pkSeqID         stime    flgs_number  proto_number           pkts  \
# count  6.685220e+05  6.685220e+05  668522.000000  668522.00000  668522.000000
# mean   3.334262e+06  1.527874e+09       1.087990       2.81228      10.912461
# std    1.929858e+05  5.722060e+05       0.645593       0.61694     270.233917
# min    3.000001e+06  1.526344e+09       1.000000       1.00000       1.000000
# 25%    3.167131e+06  1.528099e+09       1.000000       3.00000       7.000000
# 50%    3.334262e+06  1.528099e+09       1.000000       3.00000       8.000000
# 75%    3.501392e+06  1.528099e+09       1.000000       3.00000      12.000000
# max    3.668522e+06  1.529381e+09       9.000000       5.00000   70057.000000
#
#               bytes   state_number         ltime            seq  \
# count  6.685220e+05  668522.000000  6.685220e+05  668522.000000
# mean   2.039721e+03       3.761715  1.527874e+09  115211.175598
# std    2.629841e+05       0.900487  5.722058e+05   78683.515047
# min    6.000000e+01       1.000000  1.526344e+09       1.000000
# 25%    4.200000e+02       4.000000  1.528099e+09   37791.250000
# 50%    4.800000e+02       4.000000  1.528099e+09  117287.000000
# 75%    7.800000e+02       4.000000  1.528099e+09  178593.750000
# max    7.183334e+07      11.000000  1.529382e+09  262161.000000
#
#                  dur  ...  TnP_Per_Dport  AR_P_Proto_P_SrcIP  \
# count  668522.000000  ...  668522.000000        6.685220e+05
# mean       13.440747  ...     904.502742        1.820480e+03
# std        43.448549  ...    1350.237211        1.976339e+04
# min         0.000000  ...       1.000000        0.000000e+00
# 25%        12.220725  ...     700.000000        5.654380e-01
# 50%        13.658235  ...     900.000000        7.973740e-01
# 75%        13.957514  ...    1206.000000        1.074320e+00
# max      2771.485107  ...  244425.000000        2.714290e+06
#
#        AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  \
# count       668522.000000      668522.000000      668522.000000
# mean          1558.805372          97.742857          81.869814
# std           9492.700037          12.300795          26.268537
# min              0.000000           1.000000           1.000000
# 25%              0.575499         100.000000          68.000000
# 50%              0.796360         100.000000         100.000000
# 75%              1.037430         100.000000         100.000000
# max        1000000.000000         100.000000         100.000000
#
#        AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# count        6.685220e+05        6.685220e+05
# mean         2.500591e+03        2.949491e+03
# std          3.349035e+04        3.667689e+04
# min          0.000000e+00        0.000000e+00
# 25%          5.720700e-01        5.754470e-01
# 50%          7.978010e-01        7.962820e-01
# 75%          1.074630e+00        1.034220e+00
# max          3.000000e+06        2.000000e+06
#
#        Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# count                     668522.000000                    668522.000000
# mean                         920.568680                       775.625785
# std                          655.730587                       615.060700
# min                            1.000000                         1.000000
# 25%                          700.000000                       476.000000
# 50%                          904.000000                       700.000000
# 75%                         1213.000000                      1100.000000
# max                       112544.000000                    117939.000000
#
#               attack
# count  668522.000000
# mean        0.999286
# std         0.026702
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
#
# [8 rows x 37 columns]
# None
# (668522, 46)
# 30752012

# %%
#unique features
for col in data.select_dtypes(include=['object']).columns:
    print(col,data[col].nunique(),"\n",data[col].value_counts())
# Out:
# flgs 9
#  flgs
# e        654807
# eU        11159
# e s        2331
# e d         113
# e g          99
# e &           5
# e   t         4
# e *           3
# e  D          1
# Name: count, dtype: int64
# proto 5
#  proto
# udp          592145
# tcp           67202
# icmp           9030
# arp             137
# ipv6-icmp         8
# Name: count, dtype: int64
# saddr 21
#  saddr
# 192.168.100.147              182905
# 192.168.100.148              167582
# 192.168.100.150              161085
# 192.168.100.149              147091
# 192.168.100.5                  5029
# 192.168.100.3                  4673
# 192.168.100.6                    38
# 192.168.100.7                    30
# 192.168.100.4                    19
# 192.168.100.1                    16
# 192.168.100.46                   15
# 192.168.100.27                   14
# fe80::250:56ff:febe:254           6
# fe80::c0c0:aa20:45b9:bdd9         4
# 192.168.100.55                    3
# fe80::250:56ff:febe:e9d9          2
# fe80::250:56ff:febe:26db          2
# fe80::250:56ff:febe:89ee          2
# fe80::2c6a:ff9b:7e14:166a         2
# fe80::250:56ff:febe:bf1a          2
# fe80::250:56ff:febe:c038          2
# Name: count, dtype: int64
# sport 107994
#  sport
# 0x0303    8928
# 2290      1031
# 1822      1030
# 1589      1030
# 1216      1029
#           ...
# 41499        1
# 35291        1
# 41514        1
# 55055        1
# 35325        1
# Name: count, Length: 107994, dtype: int64
# daddr 84
#  daddr
# 192.168.100.3      617895
# 192.168.100.5       31384
# 192.168.100.6        4719
# 192.168.100.7        4496
# 192.168.100.149      2443
#                     ...
# 205.251.198.119         1
# 205.251.195.185         1
# 198.41.0.4              1
# 192.48.79.30            1
# 205.251.194.154         1
# Name: count, Length: 84, dtype: int64
# dport 3966
#  dport
# 80        507896
# 80         69717
# 1           6745
# 3306        4613
# 53           340
#            ...
# 0x539a         1
# 33423          1
# 0x29e4         1
# 0x2ae4         1
# 0x442c         1
# Name: count, Length: 3966, dtype: int64
# state 10
#  state
# INT    591914
# RST     59975
# URP      8928
# FIN      6385
# REQ       758
# CON       452
# ECO        70
# TST        16
# MAS        16
# NRS         8
# Name: count, dtype: int64
# category 4
#  category
# DDoS              576884
# Reconnaissance     91082
# Normal               477
# Theft                 79
# Name: count, dtype: int64
# subcategory 6
#  subcategory
# UDP                  576884
# Service_Scan          73168
# OS_Fingerprint        17914
# Normal                  477
# Keylogging               73
# Data_Exfiltration         6
# Name: count, dtype: int64

# %%
target_features = data[["attack", "category", "subcategory"]]

# %%
for col in target_features.columns:
    print(target_features[col].value_counts())
# Out:
# attack
# 1    668045
# 0       477
# Name: count, dtype: int64
# category
# DDoS              576884
# Reconnaissance     91082
# Normal               477
# Theft                 79
# Name: count, dtype: int64
# subcategory
# UDP                  576884
# Service_Scan          73168
# OS_Fingerprint        17914
# Normal                  477
# Keylogging               73
# Data_Exfiltration         6
# Name: count, dtype: int64

# %%
selected_data=data.sample(n=100000,random_state=1)

# %%
#drop the duplicates
display(selected_data.duplicated().sum())
selected_data.drop_duplicates(inplace=True)
# Out:
# np.int64(0)

# %%
#dropping specific column
selected_data.drop(columns='pkSeqID',inplace=True)

# %%
target_features = data[["attack", "category", "subcategory"]]
for col in target_features.columns:
    print(target_features[col].value_counts())
# Out:
# attack
# 1    668045
# 0       477
# Name: count, dtype: int64
# category
# DDoS              576884
# Reconnaissance     91082
# Normal               477
# Theft                 79
# Name: count, dtype: int64
# subcategory
# UDP                  576884
# Service_Scan          73168
# OS_Fingerprint        17914
# Normal                  477
# Keylogging               73
# Data_Exfiltration         6
# Name: count, dtype: int64

# %% [markdown]
# # Selected Data Loading

# %%
data=selected_data

# %%
display(data.info(),
        data.describe(),
        data.shape,
        data.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 352637 to 259749
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   stime                             100000 non-null  float64
#  1   flgs                              100000 non-null  object
#  2   flgs_number                       100000 non-null  int64
#  3   proto                             100000 non-null  object
#  4   proto_number                      100000 non-null  int64
#  5   saddr                             100000 non-null  object
#  6   sport                             100000 non-null  object
#  7   daddr                             100000 non-null  object
#  8   dport                             100000 non-null  object
#  9   pkts                              100000 non-null  int64
#  10  bytes                             100000 non-null  int64
#  11  state                             100000 non-null  object
#  12  state_number                      100000 non-null  int64
#  13  ltime                             100000 non-null  float64
#  14  seq                               100000 non-null  int64
#  15  dur                               100000 non-null  float64
#  16  mean                              100000 non-null  float64
#  17  stddev                            100000 non-null  float64
#  18  sum                               100000 non-null  float64
#  19  min                               100000 non-null  float64
#  20  max                               100000 non-null  float64
#  21  spkts                             100000 non-null  int64
#  22  dpkts                             100000 non-null  int64
#  23  sbytes                            100000 non-null  int64
#  24  dbytes                            100000 non-null  int64
#  25  rate                              100000 non-null  float64
#  26  srate                             100000 non-null  float64
#  27  drate                             100000 non-null  float64
#  28  TnBPSrcIP                         100000 non-null  int64
#  29  TnBPDstIP                         100000 non-null  int64
#  30  TnP_PSrcIP                        100000 non-null  int64
#  31  TnP_PDstIP                        100000 non-null  int64
#  32  TnP_PerProto                      100000 non-null  int64
#  33  TnP_Per_Dport                     100000 non-null  int64
#  34  AR_P_Proto_P_SrcIP                100000 non-null  float64
#  35  AR_P_Proto_P_DstIP                100000 non-null  float64
#  36  N_IN_Conn_P_DstIP                 100000 non-null  int64
#  37  N_IN_Conn_P_SrcIP                 100000 non-null  int64
#  38  AR_P_Proto_P_Sport                100000 non-null  float64
#  39  AR_P_Proto_P_Dport                100000 non-null  float64
#  40  Pkts_P_State_P_Protocol_P_DestIP  100000 non-null  int64
#  41  Pkts_P_State_P_Protocol_P_SrcIP   100000 non-null  int64
#  42  attack                            100000 non-null  int64
#  43  category                          100000 non-null  object
#  44  subcategory                       100000 non-null  object
# dtypes: float64(15), int64(21), object(9)
# memory usage: 35.1+ MB
# None
#               stime    flgs_number   proto_number           pkts  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000
# mean   1.527874e+09       1.087040       2.813300      11.210900
# std    5.716585e+05       0.642657       0.616609     303.267289
# min    1.526344e+09       1.000000       1.000000       1.000000
# 25%    1.528099e+09       1.000000       3.000000       7.000000
# 50%    1.528099e+09       1.000000       3.000000       8.000000
# 75%    1.528099e+09       1.000000       3.000000      13.000000
# max    1.529381e+09       8.000000       4.000000   59452.000000
#
#               bytes   state_number         ltime            seq  \
# count  1.000000e+05  100000.000000  1.000000e+05  100000.000000
# mean   2.506055e+03       3.763400  1.527874e+09  115068.398650
# std    3.009758e+05       0.899938  5.716584e+05   78676.795335
# min    6.000000e+01       1.000000  1.526344e+09       1.000000
# 25%    4.200000e+02       4.000000  1.528099e+09   37597.500000
# 50%    4.800000e+02       4.000000  1.528099e+09  117108.500000
# 75%    7.800000e+02       4.000000  1.528099e+09  178058.000000
# max    5.911412e+07      11.000000  1.529382e+09  262161.000000
#
#                  dur           mean  ...  TnP_Per_Dport  AR_P_Proto_P_SrcIP  \
# count  100000.000000  100000.000000  ...  100000.000000        1.000000e+05
# mean       13.444149       2.946735  ...     905.924440        1.774737e+03
# std        42.822909       1.257092  ...    1471.523542        1.943098e+04
# min         0.000000       0.000000  ...       1.000000        0.000000e+00
# 25%        12.223033       2.716355  ...     700.000000        5.654300e-01
# 50%        13.658651       3.405161  ...     902.000000        7.973920e-01
# 75%        13.957738       3.686229  ...    1209.000000        1.074320e+00
# max      1685.706909       4.981785  ...  244425.000000        2.714290e+06
#
#        AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  \
# count       100000.000000      100000.000000      100000.000000
# mean          1535.870634          97.703230          81.848490
# std           9343.032982          12.447865          26.272272
# min              0.000000           1.000000           1.000000
# 25%              0.575469         100.000000          68.000000
# 50%              0.796378         100.000000         100.000000
# 75%              1.037200         100.000000         100.000000
# max         583333.000000         100.000000         100.000000
#
#        AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# count        1.000000e+05        1.000000e+05
# mean         2.427385e+03        2.850147e+03
# std          3.202056e+04        3.469262e+04
# min          0.000000e+00        0.000000e+00
# 25%          5.654630e-01        5.754080e-01
# 50%          7.978450e-01        7.962900e-01
# 75%          1.074630e+00        1.033400e+00
# max          3.000000e+06        2.000000e+06
#
#        Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# count                      100000.00000                    100000.000000
# mean                          921.68130                       776.964090
# std                           707.41051                       696.833793
# min                             1.00000                         1.000000
# 25%                           700.00000                       476.000000
# 50%                           905.00000                       700.000000
# 75%                          1216.00000                      1100.000000
# max                        112544.00000                    112544.000000
#
#               attack
# count  100000.000000
# mean        0.999370
# std         0.025092
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
#
# [8 rows x 36 columns]
# (100000, 45)
# 4500000

# %% [markdown]
# # Data Cleaning

# %%
#cleaning nan and null values
print("NAN")
nan_counts = data.isna().sum()
print(nan_counts[nan_counts > 0])

print("\nNULL")
null_counts = data.isnull().sum()
print(null_counts[null_counts > 0])
# Out:
# NAN
# Series([], dtype: int64)
#
# NULL
# Series([], dtype: int64)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
plot=data[["attack", "category", "subcategory"]]

# %%
# Create pie charts for each column
fig, axes = plt.subplots(1, 3, figsize=(27, 9))
fig.suptitle('Network Attack Data Distribution', fontsize=18)

for i, col in enumerate(plot.columns):
    counts = plot[col].value_counts()

    # Create a pie chart with better labeling and styling
    wedges, texts, autotexts = axes[i].pie(
        counts,
        labels=None,
        autopct='%1.1f%%',
        startangle=90,
        shadow=False,
        textprops={'fontsize': 12},
        wedgeprops={'edgecolor': 'w', 'linewidth': 1}
    )


    axes[i].set_title(f'Distribution of {col}', fontsize=14)


    labels = [f'{label} ({count})' for label, count in zip(counts.index, counts)]
    axes[i].legend(wedges, labels, title=col, loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

plt.tight_layout()
plt.show()

# %% [markdown]
# # Encoding

# %%
#converting string to numerical
for col in data.select_dtypes('object').columns:
    print(col,"\n",data[col].nunique())
# Out:
# flgs
#  6
# proto
#  4
# saddr
#  13
# sport
#  58187
# daddr
#  35
# dport
#  3129
# state
#  9
# category
#  4
# subcategory
#  6

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
label=data.copy()
for col in data.select_dtypes(include=['object']).columns:
    label[col]=label[col].astype(str)
    label[col]=encoder.fit_transform(label[col])

label.sample(5)
# Out:
#                stime  flgs  flgs_number  proto  proto_number  saddr  sport  \
# 234479  1.528099e+09     0            1      3             3      4  34572
# 53962   1.528099e+09     0            1      3             3      2  10021
# 635278  1.526348e+09     0            1      2             1      4  39633
# 424791  1.528099e+09     0            1      3             3      3  34498
# 186922  1.528099e+09     0            1      3             3      1  38580
#
#         daddr  dport  pkts  ...  AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP  \
# 234479      9   2855     7  ...            0.530201                100
# 53962       9   2855    11  ...            0.809348                100
# 635278     10   2999     2  ...           55.959700                100
# 424791      9   2855     8  ...            0.559868                100
# 186922      9   2855    15  ...            1.074330                100
#
#         N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# 234479                100            0.490973            0.530201
# 53962                  97            0.802701            0.809348
# 635278                 98           52.514000          589.102000
# 424791                100            0.559713            0.559868
# 186922                100            1.074330            1.074330
#
#         Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# 234479                               756                              756
# 53962                               1109                             1067
# 635278                               190                              190
# 424791                               800                              800
# 186922                              1500                             1500
#
#         attack  category  subcategory
# 234479       1         0            5
# 53962        1         0            5
# 635278       1         2            4
# 424791       1         0            5
# 186922       1         0            5
#
# [5 rows x 45 columns]

# %% [markdown]
# # Outliar Removal

# %%
def remove_zscore_outliers(data, threshold=3.0):

    import numpy as np
    from scipy import stats

    original_rows = data.shape[0]

    # Separate normal and attack data
    normal_data = data[data['attack'] == 0]
    attack_data = data[data['attack'] == 1]

    # Apply Z-score only on numeric features
    numeric_cols = attack_data.select_dtypes(include=['number']).columns

    # Create a mask for inliers
    inlier_mask = pd.Series(True, index=attack_data.index)
    outlier_count_by_feature = {}

    print(f"Applying Z-score with threshold {threshold} on {len(numeric_cols)} numeric features...")

    # Apply Z-score to each numeric column
    for col in numeric_cols:
        if col not in ['attack', 'category', 'subcategory']:  # Skip target variables
            # Calculate Z-scores
            z_scores = np.abs(stats.zscore(attack_data[col], nan_policy='omit'))

            # Count outliers in this feature
            feature_outliers = (z_scores > threshold).sum()
            outlier_count_by_feature[col] = feature_outliers

            # Update mask - keep only rows where Z-score is below threshold
            col_mask = z_scores <= threshold
            inlier_mask = inlier_mask & col_mask

    # Extract attack data without outliers
    cleaned_attack_data = attack_data[inlier_mask]

    # Combine with normal data
    cleaned_data = pd.concat([normal_data, cleaned_attack_data])

    # Generate summary
    removed_rows = original_rows - cleaned_data.shape[0]
    percent_removed = (removed_rows / original_rows) * 100

    print(f"Outlier removal summary:")
    print(f"  - Original dataset: {original_rows} rows")
    print(f"  - Outliers removed: {removed_rows} rows ({percent_removed:.2f}%)")
    print(f"  - Final dataset: {cleaned_data.shape[0]} rows")

    # Display features with most outliers
    print("\nFeatures with most outliers:")
    outlier_df = pd.DataFrame({
        'Feature': outlier_count_by_feature.keys(),
        'Outlier Count': outlier_count_by_feature.values()
    }).sort_values('Outlier Count', ascending=False).head(10)
    print(outlier_df)

    # Visualize before/after class balance
    fig, ax = plt.subplots(1, 2, figsize=(14, 5))
    data['attack'].value_counts().plot.pie(autopct='%1.1f%%', ax=ax[0], title='Before Outlier Removal')
    cleaned_data['attack'].value_counts().plot.pie(autopct='%1.1f%%', ax=ax[1], title='After Outlier Removal')
    plt.tight_layout()
    plt.show()

    return cleaned_data

# Apply Z-score outlier removal
data = remove_zscore_outliers(label, threshold=3.0)

# Check attack distribution after outlier removal
print("\nFinal attack distribution:")
print(data['attack'].value_counts())
# Out:
# Applying Z-score with threshold 3.0 on 45 numeric features...
# Outlier removal summary:
#   - Original dataset: 100000 rows
#   - Outliers removed: 13530 rows (13.53%)
#   - Final dataset: 86470 rows
#
# Features with most outliers:
#                Feature  Outlier Count
# 12        state_number           8951
# 8                dport           4696
# 36   N_IN_Conn_P_DstIP           3106
# 7                daddr           2173
# 1                 flgs           1999
# 2          flgs_number           1668
# 35  AR_P_Proto_P_DstIP           1587
# 3                proto           1416
# 11               state           1411
# 22               dpkts           1159
# Final attack distribution:
# attack
# 1    86407
# 0       63
# Name: count, dtype: int64

# %%
data['attack'].value_counts()
# Out:
# attack
# 1    86407
# 0       63
# Name: count, dtype: int64

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
normalizer = MinMaxScaler()
data_scaled = pd.DataFrame(
    normalizer.fit_transform(data),
    columns=data.columns,
    index=data.index
)
data = data_scaled

# %% [markdown]
# # Data Balancing

# %%
leakage_features = ['attack', 'category', 'subcategory']
x = data.drop(columns=leakage_features)
y = data['attack']

y=data['attack']

# %%
from imblearn.over_sampling import SMOTE
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

print("Class distribution before SMOTE:")
print(y.value_counts())

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

smote = SMOTE(random_state=1)
X_train, y_train = smote.fit_resample(X_train, y_train)

print("\nClass distribution after SMOTE:")
print(pd.Series(y_train).value_counts())
# Out:
# Class distribution before SMOTE:
# attack
# 1.0    86407
# 0.0       63
# Name: count, dtype: int64
#
# Class distribution after SMOTE:
# attack
# 1.0    69125
# 0.0    69125
# Name: count, dtype: int64

# %% [markdown]
# # Feature Selection Methods

# %% [markdown]
# ## Filter

# %%
from sklearn.feature_selection import mutual_info_classif, SelectKBest
def mutualinfotest(data):

	selector = SelectKBest(mutual_info_classif, k=10)
	X_selected = selector.fit_transform(X_train, y_train)

	f_scores = selector.scores_

	feature_scores = pd.DataFrame({
	    'Feature': X_train.columns,
	    'F Score': f_scores,
	})

	feature_scores = feature_scores.sort_values('F Score', ascending=False)
	print(feature_scores.head(10))

mutualinfotest(data)
# Out:
#                              Feature   F Score
# 36                 N_IN_Conn_P_DstIP  0.711197
# 7                              daddr  0.696377
# 10                             bytes  0.690834
# 0                              stime  0.689548
# 13                             ltime  0.689462
# 32                      TnP_PerProto  0.689094
# 33                     TnP_Per_Dport  0.689006
# 40  Pkts_P_State_P_Protocol_P_DestIP  0.688588
# 23                            sbytes  0.688049
# 18                               sum  0.686508

# %% [markdown]
# ## Wrapper

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.metrics import accuracy_score
import time
import matplotlib.pyplot as plt

def fast_rfe_wrapper(X, y, n_features=10):
    start_time = time.time()

    print(f"Starting fast RFE wrapper to select {n_features} features")

    clf = RandomForestClassifier(
        n_estimators=50,
        max_depth=10,
        min_samples_split=10,
        random_state=42,
        n_jobs=-1
    )

    step_size = max(1, int(X.shape[1] / 20))

    rfe = RFE(
        estimator=clf,
        n_features_to_select=n_features,
        step=step_size,
        verbose=1
    )

    rfe.fit(X_train, y_train)

    selected_indices = rfe.support_
    selected_features = X.columns[selected_indices].tolist()

    X_train_selected = X_train.iloc[:, selected_indices]
    X_test_selected = X_test.iloc[:, selected_indices]

    clf.fit(X_train_selected, y_train)
    y_pred = clf.predict(X_test_selected)
    accuracy = accuracy_score(y_test, y_pred)

    execution_time = time.time() - start_time

    print(f"Feature selection completed in {execution_time:.2f} seconds")
    print(f"Selected {len(selected_features)} features")
    print(f"Model accuracy with selected features: {accuracy:.4f}")

    clf.fit(X_train.iloc[:, selected_indices], y_train)
    importance = pd.DataFrame({
        'Feature': selected_features,
        'Importance': clf.feature_importances_
    }).sort_values('Importance', ascending=False)

    print("\nSelected features ranked by importance:")
    print(importance)

    return X[selected_features]
X_wrapper_fast = fast_rfe_wrapper(x, y, n_features=10)
# Out:
# Starting fast RFE wrapper to select 10 features
# Fitting estimator with 42 features.
# Fitting estimator with 40 features.
# Fitting estimator with 38 features.
# Fitting estimator with 36 features.
# Fitting estimator with 34 features.
# Fitting estimator with 32 features.
# Fitting estimator with 30 features.
# Fitting estimator with 28 features.
# Fitting estimator with 26 features.
# Fitting estimator with 24 features.
# Fitting estimator with 22 features.
# Fitting estimator with 20 features.
# Fitting estimator with 18 features.
# Fitting estimator with 16 features.
# Fitting estimator with 14 features.
# Fitting estimator with 12 features.
# Feature selection completed in 115.95 seconds
# Selected 10 features
# Model accuracy with selected features: 1.0000
#
# Selected features ranked by importance:
#               Feature  Importance
# 9   N_IN_Conn_P_DstIP    0.265909
# 2               ltime    0.242041
# 0               stime    0.227828
# 4              stddev    0.116762
# 1               dport    0.089989
# 6                 max    0.034504
# 8  AR_P_Proto_P_SrcIP    0.018360
# 7       TnP_Per_Dport    0.002822
# 3                mean    0.001784
# 5                 sum    0.000002

# %% [markdown]
# ## Embedded

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

# Convert to NumPy arrays
x_array = x.values
y_array = y.values

# Create Random Forest model
rf = RandomForestClassifier(n_estimators=100)
rf.fit(x_array, y_array)

# Select features based on importance
selector = SelectFromModel(rf, threshold="mean")
X_selected = selector.transform(x_array)

# Get selected feature indices
selected_indices = selector.get_support()
selected_features = x.columns[selected_indices]
print(f"Selected {len(selected_features)} features: {selected_features.tolist()}")
# Out:
# Selected 10 features: ['daddr', 'state', 'state_number', 'dpkts', 'dbytes', 'rate', 'TnBPDstIP', 'TnP_PDstIP', 'TnP_PerProto', 'N_IN_Conn_P_DstIP']

# %% [markdown]
# # Classifiers

# %%
#BAGGING
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Random Forest Classification Results:")
print(f"Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

feature_importance = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': rf_model.feature_importances_
}).sort_values('Importance', ascending=False)
print("\nTop 10 Important Features:")
print(feature_importance.head(10))
# Out:
# Random Forest Classification Results:
# Accuracy: 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        12
#          1.0       1.00      1.00      1.00     17282
#
#     accuracy                           1.00     17294
#    macro avg       1.00      1.00      1.00     17294
# weighted avg       1.00      1.00      1.00     17294
#
#
# Top 10 Important Features:
#                              Feature  Importance
# 36                 N_IN_Conn_P_DstIP    0.212848
# 8                              dport    0.098884
# 0                              stime    0.093973
# 13                             ltime    0.091110
# 17                            stddev    0.077841
# 20                               max    0.070145
# 34                AR_P_Proto_P_SrcIP    0.061873
# 18                               sum    0.045643
# 16                              mean    0.041827
# 40  Pkts_P_State_P_Protocol_P_DestIP    0.040914

# %%
data.head()
# Out:
#            stime  flgs  flgs_number  proto  proto_number     saddr     sport  \
# 576901  0.000174   0.0          0.0    1.0           1.0  0.166667  0.417426
# 577349  0.004438   0.0          0.0    1.0           1.0  0.500000  0.264588
# 577105  0.002561   0.0          0.0    1.0           1.0  0.333333  0.975578
# 577003  0.001281   0.0          0.0    0.0           0.5  0.250000  0.000000
# 577135  0.002931   0.0          0.0    1.0           1.0  0.166667  0.454735
#
#            daddr     dport      pkts  ...  AR_P_Proto_P_DstIP  \
# 576901  0.911765  0.771447  0.000017  ...        9.896211e-03
# 577349  0.705882  0.771447  0.000017  ...        2.071757e-04
# 577105  0.205882  0.945903  0.000017  ...        1.832201e-07
# 577003  0.058824  0.000000  0.000017  ...        4.428317e-07
# 577135  0.382353  0.771447  0.000017  ...        2.876230e-05
#
#         N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# 576901           0.090909           0.111111        8.529789e-03
# 577349           0.030303           0.737374        1.800801e-04
# 577105           0.030303           0.171717        6.125664e-03
# 577003           0.111111           0.111111        3.731186e-07
# 577135           0.171717           0.131313        2.465567e-05
#
#         AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 576901        7.156605e-05                          0.000160
# 577349        2.183448e-04                          0.000053
# 577105        4.571430e-03                          0.000089
# 577003        2.784630e-07                          0.000409
# 577135        4.089534e-05                          0.000302
#
#         Pkts_P_State_P_Protocol_P_SrcIP  attack  category  subcategory
# 576901                         0.000062     0.0       0.5          0.0
# 577349                         0.001075     0.0       0.5          0.0
# 577105                         0.000160     0.0       0.5          0.0
# 577003                         0.000080     0.0       0.5          0.0
# 577135                         0.000098     0.0       0.5          0.0
#
# [5 rows x 45 columns]
